# %%
print("Simple Calculator")
num1 = float(input("Enter first number: "))
operator = input("Enter operator (+, -, *, /, **): ")
num2 = float(input("Enter second number: "))

# Human-style logic
if operator == "+":
    result = num1 + num2

elif operator == "-":
    result = num1 - num2

elif operator == "*":
    result = num1 * num2

elif operator == "/":
    if num2 == 0:
        result = "Error! Cannot divide by zero."
    else:
        result = num1 / num2

elif operator == "**":
    result = num1 ** num2

else:
    result = "Invalid operator!"

print("Result:", result)
# Out:
# Simple Calculator
# Enter first number:  10
# Enter operator (+, -, *, /, **):  +
# Enter second number:  12
# Result: 22.0

# %%
my_list = ["apple", "banana", 42, "orange", "grape"]

has_number = False

for item in my_list:
    if isinstance(item, (int, float)):
        has_number = True
        break
if has_number:
    print("The list contains at least one numeric value.")
else:
    print("The list does not contain any numeric values.")
# Out:
# The list contains at least one numeric value.

# %%
student = {
    "name": "Mujtaba",
    "age": 20
}

print("Before adding new key:")
print(student)

student["grade"] = "A"

print("\nAfter adding new key:")
print(student)
# Out:
# Before adding new key:
# {'name': 'John', 'age': 20}
#
# After adding new key:
# {'name': 'John', 'age': 20, 'grade': 'A'}

# %%
data = {
    "a": 10,
    "b": 20,
    "c": "hello",
    "d": 15.5,
    "e": "world"
}

total = 0
for value in data.values():
    if isinstance(value, (int, float)):
        total += value

print("Sum of all numeric values:", total)
# Out:
# Sum of all numeric values: 45.5

# %%
#  My list
my_list = [1, 2, 3, 2, 4, 5, 1, 6, 3]

duplicates = set()

seen = set()

for item in my_list:
    if item in seen:
        duplicates.add(item)
    else:
        seen.add(item)

# Print results
if duplicates:
    print("Duplicate values found:", duplicates)
else:
    print("No duplicates found in the list.")
# Out:
# Duplicate values found: {1, 2, 3}

# %%
student = {
    "name": "Mujtaba",
    "age": 22,
    "grade": "B"
}

key_to_check = "age"

if key_to_check in student:
    print(f"The key '{key_to_check}' exists in the dictionary.")
else:
    print(f"The key '{key_to_check}' does not exist in the dictionary.")
# Out:
# The key 'age' exists in the dictionary.
