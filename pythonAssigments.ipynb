# %%
print("Twinkle,twinkle, little star, \n\t How i wonder what you are! \n\t Up above the world so high, \n\t Like a diamond in the sky.\nTwinke,twinkle,little star, \n\t How i wonder what you are")
# Out:
# Twinkle,twinkle, little star,
# 	 How i wonder what you are!
# 	 Up above the world so high,
# 	 Like a diamond in the sky.
# Twinke,twinkle,little star,
# 	 How i wonder what you are

# %%
from platform import python_version
print(python_version())
# Out:
# 3.13.1

# %%
import datetime
now = datetime.datetime.now()
print(now)
# Out:
# 2026-02-26 17:52:46.783000

# %%
import math
radius =float(input("Input the circle"))

area =math.pi * radius**2
print(f"The area of the circle with radius with {radius} is: {area}")
# Out:
# Input the circle 5
# The area of the circle with radius with 5.0 is: 78.53981633974483

# %%
first_name=input("Input  your First Name")
last_name=input("Input your Last Name")
print(f"  {last_name} {first_name}")
# Out:
# Input  your First Name Mujtaba
# Input your Last Name Siddiqi
#   Siddiqi Mujtaba

# %%
x=10
y=20
x=int(input("First Number"))
y=int(input("second Number"))
z=x+y
print(z)
# Out:
# First Number 10
# second Number 20
# 30

# %%
a=1
b=2
c=3
d=4
e=5

f=int(input("First Number:"))
g=int(input("second Number:"))
h=int(input("third Number:"))
i=int(input("fourth Number:"))
j=int(input("fifth Number:"))
z=a+b+c+d+e
print(z)
# Out:
# First Number: 10
# second Number: 5
# third Number: 4
# fourth Number: 3
# fifth Number: 2
# 15

# %%
## Marksheet
Science = int(input("Enter Science Marks:"))
English = int (input("Enter English Marks:"))
Computer = int (input("Enter Computer Marks:"))
Urdu= int (input("Enter Urdu MArks:"))
obtain=Science+English+Computer+Urdu
print("Your Obtain Marks is : ",obtain)

perc = obtain / 500 * 100

print("Your Percentage is : ", perc)

if perc >=90 and perc <=100:

    print("A+ Grade")

elif perc >= 80 and perc < 90:

    print("A Grade")

elif perc >= 70 and perc < 80:

    print("B Grade")

elif perc >= 60 and perc < 70:

    print("C Grade")

elif perc >= 50 and perc < 60:

    print("D Grade")

elif perc >= 43 and perc < 50:

    print("E Grade")

else:

    print("Fail")
# Out:
# Enter Science Marks: 400
# Enter English Marks: 200
# Enter Computer Marks: 300
# Enter Urdu MArks: 450
# Your Obtain Marks is :  1350
# Your Percentage is :  270.0
# Fail

# %%
#Calcultor 
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print("\nOperations: + , - , * , /")
choice = input("Select operation: ")

if choice == '+':
    print(f"Result: {num1 + num2}")
elif choice == '-':
    print(f"Result: {num1 - num2}")
elif choice == '*':
    print(f"Result: {num1 * num2}")
elif choice == '/':
    if num2 == 0:
        print("Error: Cannot divide by zero.")
    else:
        print(f"Result: {num1 / num2}")
else:
    print("Invalid choice!")
# Out:
# Enter first number:  10
# Enter second number:  10
# Operations: + , - , * , /
# Select operation:  +
# Result: 20
